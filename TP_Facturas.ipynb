-- %% [markdown]
-- # [TP_Facturas]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TP_Facturas]    Script Date: 11/6/2024 18:22:04 ******/
CREATE DATABASE [TP_Facturas]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TP_Facturas', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\TP_Facturas.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TP_Facturas_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\TP_Facturas_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [TP_Facturas] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TP_Facturas].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TP_Facturas] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TP_Facturas] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TP_Facturas] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TP_Facturas] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TP_Facturas] SET ARITHABORT OFF 
GO
ALTER DATABASE [TP_Facturas] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TP_Facturas] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TP_Facturas] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TP_Facturas] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TP_Facturas] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TP_Facturas] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TP_Facturas] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TP_Facturas] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TP_Facturas] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TP_Facturas] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TP_Facturas] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TP_Facturas] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TP_Facturas] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TP_Facturas] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TP_Facturas] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TP_Facturas] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TP_Facturas] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TP_Facturas] SET RECOVERY FULL 
GO
ALTER DATABASE [TP_Facturas] SET  MULTI_USER 
GO
ALTER DATABASE [TP_Facturas] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TP_Facturas] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TP_Facturas] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TP_Facturas] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TP_Facturas] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TP_Facturas] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'TP_Facturas', N'ON'
GO
ALTER DATABASE [TP_Facturas] SET QUERY_STORE = ON
GO
ALTER DATABASE [TP_Facturas] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Clientes]

-- %%
USE [TP_Facturas]
GO

-- %%
/****** Object:  Table [dbo].[Clientes]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Clientes](
	[dni] [varchar](10) NOT NULL,
	[apellido] [varchar](50) NOT NULL,
	[nombre] [varchar](50) NOT NULL,
	[fechaNacimiento] [date] NOT NULL,
	[mail] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Clientes] PRIMARY KEY CLUSTERED 
(
	[dni] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DetalleVentas]

-- %%
/****** Object:  Table [dbo].[DetalleVentas]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DetalleVentas](
	[idDetalle] [int] IDENTITY(1,1) NOT NULL,
	[idVenta] [int] NOT NULL,
	[idProducto] [int] NOT NULL,
	[cantidad] [int] NOT NULL,
 CONSTRAINT [PK_DetalleVentas] PRIMARY KEY CLUSTERED 
(
	[idDetalle] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[idProducto] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [varchar](30) NOT NULL,
	[paisImportador] [varchar](30) NOT NULL,
	[precio] [money] NOT NULL,
	[stock] [int] NOT NULL,
 CONSTRAINT [PK_Productos] PRIMARY KEY CLUSTERED 
(
	[idProducto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Telefonos]

-- %%
/****** Object:  Table [dbo].[Telefonos]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Telefonos](
	[idTelefono] [int] IDENTITY(1,1) NOT NULL,
	[dni] [varchar](10) NOT NULL,
	[numero] [int] NOT NULL,
 CONSTRAINT [PK_Telefonos] PRIMARY KEY CLUSTERED 
(
	[idTelefono] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ventas]

-- %%
/****** Object:  Table [dbo].[Ventas]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ventas](
	[idVenta] [int] IDENTITY(1,1) NOT NULL,
	[fecha] [date] NOT NULL,
	[dniCliente] [varchar](10) NOT NULL,
 CONSTRAINT [PK_Ventas] PRIMARY KEY CLUSTERED 
(
	[idVenta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_DetalleVentas_Productos]

-- %%
ALTER TABLE [dbo].[DetalleVentas]  WITH CHECK ADD  CONSTRAINT [FK_DetalleVentas_Productos] FOREIGN KEY([idProducto])
REFERENCES [dbo].[Productos] ([idProducto])
GO
ALTER TABLE [dbo].[DetalleVentas] CHECK CONSTRAINT [FK_DetalleVentas_Productos]
GO

-- %% [markdown]
-- # [FK_DetalleVentas_Ventas]

-- %%
ALTER TABLE [dbo].[DetalleVentas]  WITH CHECK ADD  CONSTRAINT [FK_DetalleVentas_Ventas] FOREIGN KEY([idVenta])
REFERENCES [dbo].[Ventas] ([idVenta])
GO
ALTER TABLE [dbo].[DetalleVentas] CHECK CONSTRAINT [FK_DetalleVentas_Ventas]
GO

-- %% [markdown]
-- # [FK_Telefonos_Clientes]

-- %%
ALTER TABLE [dbo].[Telefonos]  WITH CHECK ADD  CONSTRAINT [FK_Telefonos_Clientes] FOREIGN KEY([dni])
REFERENCES [dbo].[Clientes] ([dni])
GO
ALTER TABLE [dbo].[Telefonos] CHECK CONSTRAINT [FK_Telefonos_Clientes]
GO

-- %% [markdown]
-- # [FK_Ventas_Clientes]

-- %%
ALTER TABLE [dbo].[Ventas]  WITH CHECK ADD  CONSTRAINT [FK_Ventas_Clientes] FOREIGN KEY([dniCliente])
REFERENCES [dbo].[Clientes] ([dni])
GO
ALTER TABLE [dbo].[Ventas] CHECK CONSTRAINT [FK_Ventas_Clientes]
GO

-- %% [markdown]
-- # [dbo].[sp_ActualizarPrecios]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ActualizarPrecios]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_ActualizarPrecios]
	@pPorcentaje DECIMAL
AS
BEGIN
UPDATE [dbo].[Productos]
   SET precio = precio * (1 + @pPorcentaje / 100)
END
GO

-- %% [markdown]
-- # [dbo].[sp_BorrarTelefono]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_BorrarTelefono]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_BorrarTelefono]
	@pidTelefono int

AS
BEGIN
	DECLARE @dni varchar(10)
	DECLARE @numeroTelefonos int

	SELECT @dni				= dni FROM Telefonos WHERE idTelefono = @pidTelefono
	SELECT @numeroTelefonos = COUNT(*)  FROM Telefonos WHERE dni = @dni

	IF @numeroTelefonos > 1
	BEGIN
		DELETE FROM [dbo].[Telefonos]
		WHERE idTelefono = @pidTelefono
	END
	ELSE
	PRINT 'No se puede borrar este telefono'
END
GO

-- %% [markdown]
-- # [dbo].[sp_InsertarCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_InsertarCliente]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_InsertarCliente]
	@pDni varchar(10),
	@pApellido varchar(50),
	@pNombre varchar(50),
	@pFechaNacimiento date,
	@pMail varchar(50)
AS
BEGIN

INSERT INTO [dbo].[Clientes]
           ([dni]
           ,[apellido]
           ,[nombre]
           ,[fechaNacimiento]
           ,[mail])
     VALUES
           (@pDni,
			@pApellido,
			@pNombre,
			@pFechaNacimiento,
			@pMail)
END
GO

-- %% [markdown]
-- # [dbo].[sp_InsertarDetalle]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_InsertarDetalle]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_InsertarDetalle]
	@pIdVenta int,
	@pIdProducto int,
	@pCantidad int
AS
BEGIN

DECLARE @stock int
SELECT @stock= stock FROM Productos WHERE idProducto = @pIdProducto
IF @stock > 5
	IF @stock > @pCantidad
		BEGIN
		INSERT INTO [dbo].[DetalleVentas]
				   ([idVenta]
				   ,[idProducto]
				   ,[cantidad])
			 VALUES
				   (@pIdVenta,
					@pIdProducto,
					@pCantidad)

			UPDATE Productos
            SET stock = stock - @pCantidad
            WHERE idProducto = @pIdProducto
		END
	ELSE
		PRINT 'No se puede realizar la venta'
		
ELSE
	PRINT 'Falta de stock'
END
GO

-- %% [markdown]
-- # [dbo].[sp_InsertarProducto]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_InsertarProducto]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_InsertarProducto]
	@pNombre varchar(30),
	@pPaisImportador varchar(30),
	@pPrecio money,
	@pStock int
AS
BEGIN

INSERT INTO [dbo].[Productos]
           ([nombre]
           ,[paisImportador]
           ,[precio]
           ,[stock])
     VALUES
           (@pNombre,
		   @pPaisImportador,
		   @pPrecio,
		   @pStock)

END
GO

-- %% [markdown]
-- # [dbo].[sp_InsertarVenta]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_InsertarVenta]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_InsertarVenta]
	@pFecha date,
	@pDniCliente varchar(10)
AS
BEGIN

INSERT INTO [dbo].[Ventas]
           ([fecha]
           ,[dniCliente])
     VALUES
           (@pFecha,
			@pDniCliente)

END
GO

-- %% [markdown]
-- # [dbo].[sp_ListarVentasXCliente]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ListarVentasXCliente]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_ListarVentasXCliente]
	@pDniCliente varchar(10),
	@pFecha1 date,
	@pFecha2 date
AS
BEGIN

SELECT [idVenta]
      ,[fecha]
      ,[dniCliente]
  FROM Ventas
  WHERE dniCliente= @pDniCliente
  AND Ventas.fecha BETWEEN @pFecha1 AND @pFecha2

END
GO

-- %% [markdown]
-- # [dbo].[sp_ObtenerProductosPorPais]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ObtenerProductosPorPais]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_ObtenerProductosPorPais]
	@pPais varchar(30)
AS
BEGIN

SELECT [idProducto]
      ,[nombre]
      ,[paisImportador]
      ,[precio]
      ,[stock]
  FROM [dbo].[Productos]
  WHERE paisImportador = @pPais

END
GO

-- %% [markdown]
-- # [dbo].[sp_VerificarStock]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_VerificarStock]    Script Date: 11/6/2024 18:22:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_VerificarStock]
	@pIdProducto int
AS
BEGIN

SELECT [stock]
  FROM [dbo].[Productos]
  WHERE idProducto = @pIdProducto
END
GO

-- %% [markdown]
-- # [TP_Facturas]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TP_Facturas] SET  READ_WRITE 
GO

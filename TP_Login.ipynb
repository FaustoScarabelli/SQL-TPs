-- %% [markdown]
-- # [TP_Login]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [TP_Login]    Script Date: 11/6/2024 18:20:30 ******/
CREATE DATABASE [TP_Login]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'TP_Login', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\TP_Login.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'TP_Login_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\TP_Login_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [TP_Login] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [TP_Login].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [TP_Login] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [TP_Login] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [TP_Login] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [TP_Login] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [TP_Login] SET ARITHABORT OFF 
GO
ALTER DATABASE [TP_Login] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [TP_Login] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [TP_Login] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [TP_Login] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [TP_Login] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [TP_Login] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [TP_Login] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [TP_Login] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [TP_Login] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [TP_Login] SET  DISABLE_BROKER 
GO
ALTER DATABASE [TP_Login] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [TP_Login] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [TP_Login] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [TP_Login] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [TP_Login] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [TP_Login] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [TP_Login] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [TP_Login] SET RECOVERY FULL 
GO
ALTER DATABASE [TP_Login] SET  MULTI_USER 
GO
ALTER DATABASE [TP_Login] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [TP_Login] SET DB_CHAINING OFF 
GO
ALTER DATABASE [TP_Login] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [TP_Login] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [TP_Login] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [TP_Login] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'TP_Login', N'ON'
GO
ALTER DATABASE [TP_Login] SET QUERY_STORE = ON
GO
ALTER DATABASE [TP_Login] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[TipoUsuario]

-- %%
USE [TP_Login]
GO

-- %%
/****** Object:  Table [dbo].[TipoUsuario]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TipoUsuario](
	[tipoUsuarioId] [int] IDENTITY(1,1) NOT NULL,
	[tipoUsuario] [varchar](50) NOT NULL,
 CONSTRAINT [PK_TipoUsuario] PRIMARY KEY CLUSTERED 
(
	[tipoUsuarioId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[nombreUsuario] [varchar](50) NOT NULL,
	[contraseña] [varchar](30) NOT NULL,
	[apellido] [varchar](30) NOT NULL,
	[nombre] [varchar](30) NOT NULL,
	[mail] [varchar](50) NOT NULL,
	[tipoUsuarioId] [int] NOT NULL,
 CONSTRAINT [PK_Usuarios] PRIMARY KEY CLUSTERED 
(
	[nombreUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Usuarios_TipoUsuario]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD  CONSTRAINT [FK_Usuarios_TipoUsuario] FOREIGN KEY([tipoUsuarioId])
REFERENCES [dbo].[TipoUsuario] ([tipoUsuarioId])
GO
ALTER TABLE [dbo].[Usuarios] CHECK CONSTRAINT [FK_Usuarios_TipoUsuario]
GO

-- %% [markdown]
-- # [dbo].[sp_EliminarPerfil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_EliminarPerfil]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_EliminarPerfil]
	@pTipoUsuarioId int,
	@pPin int
AS
BEGIN

DELETE FROM [dbo].[TipoUsuario]
      WHERE tipoUsuarioId = @pTipoUsuarioId AND @pPin = 1234

END
GO

-- %% [markdown]
-- # [dbo].[sp_EliminarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_EliminarUsuario]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_EliminarUsuario]
	@pNombreUsuario varchar(50)
AS
BEGIN

DELETE FROM [dbo].[Usuarios]
      WHERE nombreUsuario = @pNombreUsuario
END
GO

-- %% [markdown]
-- # [dbo].[sp_ListarUsuariosxPerfil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ListarUsuariosxPerfil]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_ListarUsuariosxPerfil]
	@pTipoUsuario varchar(50)
AS
BEGIN
	SELECT * FROM Usuarios u INNER JOIN TipoUsuario t ON u.tipoUsuarioId = t.tipoUsuarioId
	WHERE t.tipoUsuario = @pTipoUsuario
END
GO

-- %% [markdown]
-- # [dbo].[sp_Login]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_Login]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_Login]
		@pNombreUsuario varchar(30) = null,
		@pContraseña varchar(30) = null

AS
BEGIN
	IF EXISTS (SELECT 1 FROM Usuarios WHERE nombreUsuario = @pNombreUsuario AND contraseña = @pContraseña)
	BEGIN
		SELECT * FROM Usuarios WHERE nombreUsuario = @pNombreUsuario AND contraseña = @pContraseña
	END
	ELSE
	BEGIN
		PRINT 'Usuario o contraseña incorrecta'
	END
END

GO

-- %% [markdown]
-- # [dbo].[sp_ModificarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_ModificarUsuario]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_ModificarUsuario]
	@pNombreUsuario varchar(59),
	@pContraseña varchar(30) = NULL,
	@pApellido varchar(30) = NULL,
	@pNombre varchar(30) = NULL,
	@pMail varchar(50) = NULL,
	@pTipoUsuarioId int = NULL
AS
BEGIN

UPDATE [dbo].[Usuarios]
   SET [contraseña] = IIF(@pContraseña is null, contraseña, @pContraseña)
      ,[apellido] = IIF(@pApellido is null, apellido, @pApellido)
      ,[nombre] = IIF(@pNombre is null, nombre, @pNombre)
      ,[mail] = IIF(@pMail is null, mail, @pMail)
      ,[tipoUsuarioId] = IIF(@pTipoUsuarioId is null, tipoUsuarioId, @pTipoUsuarioId)
 WHERE nombreUsuario = @pNombreUsuario
END
GO

-- %% [markdown]
-- # [dbo].[sp_RegistrarPerfil]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_RegistrarPerfil]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[sp_RegistrarPerfil]
	@pTipoUsuario varchar(50)
AS
BEGIN
INSERT INTO TipoUsuario
     VALUES
           (@pTipoUsuario)
END
GO

-- %% [markdown]
-- # [dbo].[sp_RegistrarUsuario]

-- %%
/****** Object:  StoredProcedure [dbo].[sp_RegistrarUsuario]    Script Date: 11/6/2024 18:20:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create Procedure [dbo].[sp_RegistrarUsuario]
	@pUsuarioId varchar(30),
	@pContraseña varchar(30),
	@pApellido varchar(30),
	@pNombre varchar(30),
	@pMail varchar(50),
	@pTipoUsuarioId int

AS

INSERT INTO [dbo].[Usuarios]
           ([nombreUsuario]
           ,[contraseña]
           ,[apellido]
           ,[nombre]
           ,[mail]
           ,[tipoUsuarioId])
     VALUES
			(
			 @pUsuarioId,
			 @pContraseña,
			 @pApellido ,
			 @pNombre,
			 @pMail,
			 @pTipoUsuarioId
			 )
    

GO

-- %% [markdown]
-- # [TP_Login]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [TP_Login] SET  READ_WRITE 
GO
